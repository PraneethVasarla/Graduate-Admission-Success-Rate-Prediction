# %% [markdown]
# # MODEL BUILDING

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
from sklearn import preprocessing,model_selection

# %%
df = pd.read_csv('Admission_Predict.csv')

# %%
X = np.array(df.drop(['Serial No.',"University Rating","Research","Chance of Admit "], 1))
y = np.array(df['Chance of Admit '])

# %%
clf = LinearRegression()

# %%
X_train,X_test,y_train,y_test = model_selection.train_test_split(X,y,test_size=0.2)

# %%
clf.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
clf.score(X_test,y_test)
# Out:
# 0.7837275334274144

# %%
testing_fin = pd.read_csv('Admission_Predict_Ver1.1.csv')

# %%
testing = np.array(testing.drop(['Serial No.','University Rating','Research','Chance of Admit '],1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-a08187cb543e> in <module>()
# ----> 1 testing = np.array(testing.drop(['Serial No.','University Rating','Research','Chance of Admit '],1))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'drop'

# %%
preds = clf.predict(testing)

# %%
testing_fin['Predicted'] = preds

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
testing_fin
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# 5             6        330          115                  5  4.5   3.0  9.34
# 6             7        321          109                  3  3.0   4.0  8.20
# 7             8        308          101                  2  3.0   4.0  7.90
# 8             9        302          102                  1  2.0   1.5  8.00
# 9            10        323          108                  3  3.5   3.0  8.60
# 10           11        325          106                  3  3.5   4.0  8.40
# ...

# %%
testing_fin.to_csv('predicted.csv')
